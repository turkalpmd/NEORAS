# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
# Dosya yolu
file_path = r".\001-2023-04-18.txt"
# Veriyi pandas ile okuma
data = pd.read_csv(file_path, delimiter=" ", header=None)
data[0].plot()

# %%
# Out:
# <Axes: >
